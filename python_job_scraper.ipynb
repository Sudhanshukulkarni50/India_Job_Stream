# %%
import requests
import json
import time
import uuid
from datetime import datetime
from azure.storage.blob import BlobServiceClient
from urllib.parse import quote_plus

# %%
# ---------- ADZUNA API (replace) ----------
APP_ID = "ba3ff03e"
APP_KEY = "1f22402e03b967fade52b904cf16bebf"

# ---------- AZURE (replace) ----------
connection_string = "DefaultEndpointsProtocol=https;AccountName=employeedata12113;AccountKey=dUfd9FfMWS/Qn6ineiQHIUg/77TL35StiKDnCEsfdhBQDpkQhm0UPN667Lr66o55BW6qOUCRy7qU+ASthpFngw==;EndpointSuffix=core.windows.net"
container_name = "jobdata"

# ---------- JOB QUERY SETTINGS ----------
# You can change 'what' to different roles/keywords or leave generic to collect many categories
what = ""          # empty = all, or "data analyst", "software engineer" etc.
results_per_page = 50   # max per page
pages_per_cycle = 2     # how many pages per city iteration (increase to collect more at once)

# Time control
num_cycles = 3     # how many cycles (rounds) you want to run
interval_between_requests = 1  # seconds between each API call to respect rate limits

# Connect to Azure
blob_service_client = BlobServiceClient.from_connection_string(connection_string)
container_client = blob_service_client.get_container_client(container_name)
print("Azure container client ready ->", container_name)
# Out:
# Azure container client ready -> jobdata

# %%
cities = [
 "Delhi","Mumbai","Bengaluru","Hyderabad","Ahmedabad","Chennai","Kolkata","Pune","Jaipur","Surat",
 "Lucknow","Kanpur","Nagpur","Indore","Bhopal","Visakhapatnam","Patna","Vadodara","Ghaziabad",
 "Ludhiana","Agra","Nashik","Faridabad","Meerut","Rajkot","Vasai-Virar","Varanasi","Srinagar",
 "Aurangabad","Dhanbad","Amritsar","Navi Mumbai","Howrah","Ranchi","Gwalior","Jabalpur",
 "Coimbatore","Vijayawada","Madurai","Raipur","Kota","Chandigarh","Guwahati","Solapur",
 "Hubli-Dharwad","Mysore","Noida","Jamshedpur","Bhilai","Cuttack","Kochi","Dehradun"
]
# (this is a good starting set; you can expand later)

# %%
def fetch_jobs_for_city(city, page=1, results_per_page=50, what=""):
    """
    Returns list of job dicts for the city and page.
    """
    base = "https://api.adzuna.com/v1/api/jobs/in/search/{page}"
    url = base.format(page=page)
    params = {
        "app_id": APP_ID,
        "app_key": APP_KEY,
        "results_per_page": results_per_page,
        "what": what,
        "where": city,
        "content-type": "application/json"
    }
    # build query string (requests will handle encoding)
    resp = requests.get(url, params=params, timeout=15)
    if resp.status_code != 200:
        print(f"Warning: status {resp.status_code} for {city} page {page}: {resp.text[:200]}")
        return []
    data = resp.json()
    return data.get("results", [])

# %%
def clean_title(title):
    # Remove " - Bangalore" or " – Delhi" etc.
    if " - " in title:
        return title.split(" - ")[0]
    if " – " in title:
        return title.split(" – ")[0]
    return title


def normalize_job_result(job):
    cleaned_title = clean_title(job.get("title", ""))

    return {
        "job_id": job.get("id"),
        "title": cleaned_title,  # cleaned title here
        "company": job.get("company", {}).get("display_name"),
        "location": job.get("location", {}).get("display_name"),
        "salary_min": job.get("salary_min"),
        "salary_max": job.get("salary_max"),
        "contract_type": job.get("contract_type"),
        "category": job.get("category", {}).get("label"),  # INDUSTRY
        "description_snippet": job.get("description"),
        "created": job.get("created"),
        "redirect_url": job.get("redirect_url"),
        "skills": job.get("tags"),
        "source": "adzuna",
        "ingested_at": datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S")
    }

# %%
def upload_json_to_blob(obj, prefix="jobs"):
    j = json.dumps(obj, ensure_ascii=False)
    blob_name = f"{prefix}_{obj.get('job_id','')}_{uuid.uuid4()}.json"
    # optional: encode blob_name safe
    blob_name = quote_plus(blob_name)
    container_client.upload_blob(blob_name, j, overwrite=True)
    return blob_name

# %%
print("Starting Adzuna -> Azure job ingestion loop")

count = 0
for cycle in range(num_cycles):
    print(f"\n=== Cycle {cycle+1}/{num_cycles} ===")
    for city in cities:
        for page in range(1, pages_per_cycle + 1):
            jobs = fetch_jobs_for_city(city, page=page, results_per_page=results_per_page, what=what)
            if not jobs:
                time.sleep(interval_between_requests)
                continue
            for job in jobs:
                normalized = normalize_job_result(job)
                blob_name = upload_json_to_blob(normalized, prefix=f"adzuna_job_{city.replace(' ','_')}")
                count += 1
                if count % 50 == 0:
                    print(f"Uploaded {count} job files so far...")
            time.sleep(interval_between_requests)   # small pause to respect rate limits
    print(f"Cycle {cycle+1} done. Total uploaded so far: {count}")

print(f"\nFinished. Total job files uploaded: {count}")
# Out:
# Starting Adzuna -> Azure job ingestion loop
#
# === Cycle 1/3 ===
# C:\Users\Sudhanshu\AppData\Local\Temp\ipykernel_13852\1487396441.py:27: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "ingested_at": datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S")
# Uploaded 50 job files so far...
# Uploaded 100 job files so far...
# Uploaded 150 job files so far...
# Uploaded 200 job files so far...
# Uploaded 250 job files so far...
# Uploaded 300 job files so far...
# Uploaded 350 job files so far...
# Uploaded 400 job files so far...
# Uploaded 450 job files so far...
# Uploaded 500 job files so far...
# Uploaded 550 job files so far...
# Uploaded 600 job files so far...
# Uploaded 650 job files so far...
# Uploaded 700 job files so far...
# Uploaded 750 job files so far...
# Uploaded 800 job files so far...
# Uploaded 850 job files so far...
# Uploaded 900 job files so far...
# Uploaded 950 job files so far...
# Uploaded 1000 job files so far...
# Uploaded 1050 job files so far...
# Uploaded 1100 job files so far...
# Uploaded 1150 job files so far...
# Uploaded 1200 job files so far...
# Uploaded 1250 job files so far...
# Uploaded 1300 job files so far...
# Uploaded 1350 job files so far...
# Uploaded 1400 job files so far...
# Uploaded 1450 job files so far...
# Uploaded 1500 job files so far...
# Uploaded 1550 job files so far...
# Uploaded 1600 job files so far...
# Uploaded 1650 job files so far...
# Uploaded 1700 job files so far...
# Uploaded 1750 job files so far...
# Uploaded 1800 job files so far...
# Uploaded 1850 job files so far...
# Uploaded 1900 job files so far...
# Uploaded 1950 job files so far...
# Uploaded 2000 job files so far...
# Uploaded 2050 job files so far...
# Uploaded 2100 job files so far...
# Uploaded 2150 job files so far...
# Uploaded 2200 job files so far...
# Uploaded 2250 job files so far...
# Uploaded 2300 job files so far...
# Uploaded 2350 job files so far...
# Uploaded 2400 job files so far...
# Uploaded 2450 job files so far...
# Uploaded 2500 job files so far...
# Uploaded 2550 job files so far...
# Uploaded 2600 job files so far...
# Uploaded 2650 job files so far...
# Uploaded 2700 job files so far...
# Uploaded 2750 job files so far...
# Uploaded 2800 job files so far...
# Uploaded 2850 job files so far...
# Uploaded 2900 job files so far...
# Uploaded 2950 job files so far...
# Uploaded 3000 job files so far...
# Uploaded 3050 job files so far...
# Uploaded 3100 job files so far...
# Uploaded 3150 job files so far...
# Uploaded 3200 job files so far...
# Uploaded 3250 job files so far...
# Uploaded 3300 job files so far...
# Uploaded 3350 job files so far...
# Uploaded 3400 job files so far...
# Uploaded 3450 job files so far...
# Uploaded 3500 job files so far...
# Uploaded 3550 job files so far...
# Uploaded 3600 job files so far...
# Uploaded 3650 job files so far...
# Uploaded 3700 job files so far...
# Uploaded 3750 job files so far...
# Uploaded 3800 job files so far...
# Uploaded 3850 job files so far...
# Uploaded 3900 job files so far...
# Uploaded 3950 job files so far...
# Uploaded 4000 job files so far...
# Uploaded 4050 job files so far...
# Uploaded 4100 job files so far...
# Uploaded 4150 job files so far...
# Uploaded 4200 job files so far...
# Uploaded 4250 job files so far...
# Uploaded 4300 job files so far...
# Uploaded 4350 job files so far...
# Uploaded 4400 job files so far...
# Uploaded 4450 job files so far...
# Cycle 1 done. Total uploaded so far: 4480
#
# === Cycle 2/3 ===
# Uploaded 4500 job files so far...
# Uploaded 4550 job files so far...
# Uploaded 4600 job files so far...
# Uploaded 4650 job files so far...
# Uploaded 4700 job files so far...
# Uploaded 4750 job files so far...
# Uploaded 4800 job files so far...
# Uploaded 4850 job files so far...
# Uploaded 4900 job files so far...
# Uploaded 4950 job files so far...
# Uploaded 5000 job files so far...
# Uploaded 5050 job files so far...
# Uploaded 5100 job files so far...
# Uploaded 5150 job files so far...
# Uploaded 5200 job files so far...
# Uploaded 5250 job files so far...
# Uploaded 5300 job files so far...
# Uploaded 5350 job files so far...
# Uploaded 5400 job files so far...
# Uploaded 5450 job files so far...
# Uploaded 5500 job files so far...
# Uploaded 5550 job files so far...
# Uploaded 5600 job files so far...
# Uploaded 5650 job files so far...
# Uploaded 5700 job files so far...
# Uploaded 5750 job files so far...
# Uploaded 5800 job files so far...
# Uploaded 5850 job files so far...
# Uploaded 5900 job files so far...
# Uploaded 5950 job files so far...
# Uploaded 6000 job files so far...
# Uploaded 6050 job files so far...
# Uploaded 6100 job files so far...
# Uploaded 6150 job files so far...
# Uploaded 6200 job files so far...
# Uploaded 6250 job files so far...
# Uploaded 6300 job files so far...
# Uploaded 6350 job files so far...
# Uploaded 6400 job files so far...
# Uploaded 6450 job files so far...
# Uploaded 6500 job files so far...
# Uploaded 6550 job files so far...
# Uploaded 6600 job files so far...
# Uploaded 6650 job files so far...
# Uploaded 6700 job files so far...
# Uploaded 6750 job files so far...
# Uploaded 6800 job files so far...
# Uploaded 6850 job files so far...
# Uploaded 6900 job files so far...
# Uploaded 6950 job files so far...
# Uploaded 7000 job files so far...
# Uploaded 7050 job files so far...
# Uploaded 7100 job files so far...
# Uploaded 7150 job files so far...
# Uploaded 7200 job files so far...
# Uploaded 7250 job files so far...
# Uploaded 7300 job files so far...
# Uploaded 7350 job files so far...
# Uploaded 7400 job files so far...
# Uploaded 7450 job files so far...
# Uploaded 7500 job files so far...
# Uploaded 7550 job files so far...
# Uploaded 7600 job files so far...
# Uploaded 7650 job files so far...
# Uploaded 7700 job files so far...
# Uploaded 7750 job files so far...
# Uploaded 7800 job files so far...
# Uploaded 7850 job files so far...
# Uploaded 7900 job files so far...
# Uploaded 7950 job files so far...
# Uploaded 8000 job files so far...
# Uploaded 8050 job files so far...
# Uploaded 8100 job files so far...
# Uploaded 8150 job files so far...
# Uploaded 8200 job files so far...
# Uploaded 8250 job files so far...
# Uploaded 8300 job files so far...
# Uploaded 8350 job files so far...
# Uploaded 8400 job files so far...
# Uploaded 8450 job files so far...
# Uploaded 8500 job files so far...
# Uploaded 8550 job files so far...
# Uploaded 8600 job files so far...
# Uploaded 8650 job files so far...
# Uploaded 8700 job files so far...
# Uploaded 8750 job files so far...
# Uploaded 8800 job files so far...
# Uploaded 8850 job files so far...
# Uploaded 8900 job files so far...
# Uploaded 8950 job files so far...
# Cycle 2 done. Total uploaded so far: 8960
#
# === Cycle 3/3 ===
# Uploaded 9000 job files so far...
# Uploaded 9050 job files so far...
# Uploaded 9100 job files so far...
# Uploaded 9150 job files so far...
# Uploaded 9200 job files so far...
# Uploaded 9250 job files so far...
# Uploaded 9300 job files so far...
# Uploaded 9350 job files so far...
# Uploaded 9400 job files so far...
# Uploaded 9450 job files so far...
# Uploaded 9500 job files so far...
# Uploaded 9550 job files so far...
# Uploaded 9600 job files so far...
# Uploaded 9650 job files so far...
# Uploaded 9700 job files so far...
# Uploaded 9750 job files so far...
# Uploaded 9800 job files so far...
# Uploaded 9850 job files so far...
# Uploaded 9900 job files so far...
# Uploaded 9950 job files so far...
# Uploaded 10000 job files so far...
# Uploaded 10050 job files so far...
# Uploaded 10100 job files so far...
# Uploaded 10150 job files so far...
# Uploaded 10200 job files so far...
# Uploaded 10250 job files so far...
# Uploaded 10300 job files so far...
# Uploaded 10350 job files so far...
# Uploaded 10400 job files so far...
# Uploaded 10450 job files so far...
# Uploaded 10500 job files so far...
# Uploaded 10550 job files so far...
# Uploaded 10600 job files so far...
# Uploaded 10650 job files so far...
# Uploaded 10700 job files so far...
# Uploaded 10750 job files so far...
# Uploaded 10800 job files so far...
# Uploaded 10850 job files so far...
# Uploaded 10900 job files so far...
# Uploaded 10950 job files so far...
# Uploaded 11000 job files so far...
# Uploaded 11050 job files so far...
# Uploaded 11100 job files so far...
# Uploaded 11150 job files so far...
# Uploaded 11200 job files so far...
# Uploaded 11250 job files so far...
# Uploaded 11300 job files so far...
# Uploaded 11350 job files so far...
# Uploaded 11400 job files so far...
# Uploaded 11450 job files so far...
# Uploaded 11500 job files so far...
# Uploaded 11550 job files so far...
# Uploaded 11600 job files so far...
# Uploaded 11650 job files so far...
# Uploaded 11700 job files so far...
# Uploaded 11750 job files so far...
# Uploaded 11800 job files so far...
# Uploaded 11850 job files so far...
# Uploaded 11900 job files so far...
# Uploaded 11950 job files so far...
# Uploaded 12000 job files so far...
# Uploaded 12050 job files so far...
# Uploaded 12100 job files so far...
# Uploaded 12150 job files so far...
# Uploaded 12200 job files so far...
# Uploaded 12250 job files so far...
# Uploaded 12300 job files so far...
# Uploaded 12350 job files so far...
# Uploaded 12400 job files so far...
# Uploaded 12450 job files so far...
# Uploaded 12500 job files so far...
# Uploaded 12550 job files so far...
# Uploaded 12600 job files so far...
# Uploaded 12650 job files so far...
# Uploaded 12700 job files so far...
# Uploaded 12750 job files so far...
# Uploaded 12800 job files so far...
# Uploaded 12850 job files so far...
# Uploaded 12900 job files so far...
# Uploaded 12950 job files so far...
# Uploaded 13000 job files so far...
# Uploaded 13050 job files so far...
# Uploaded 13100 job files so far...
# Uploaded 13150 job files so far...
# Uploaded 13200 job files so far...
# Uploaded 13250 job files so far...
# Uploaded 13300 job files so far...
# Uploaded 13350 job files so far...
# Uploaded 13400 job files so far...
# Cycle 3 done. Total uploaded so far: 13440
#
# Finished. Total job files uploaded: 13440
